# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
# import tensorflow as tf
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
merged_diabetes_df = pd.read_csv('resources/merged_scaled.csv')
merged_diabetes_df.head()
# Out:
#    Unnamed: 0  diabetes   insulin  worry_food  food_not_last  balanced_meals  \
# 0           0  0.291409  0.203629    0.623139       0.564502        0.532658
# 1           1  0.291409  0.203629    0.623139       0.564502        0.532658
# 2           2  0.291409  0.203629   -0.901911      -1.108582       -1.117095
# 3           3  0.291409  0.203629    0.623139       0.564502        0.532658
# 4           4 -2.184487 -4.910885    0.623139       0.564502        0.532658
#
#    food_security  emergency_food  food_stamp  monthly_income  ...  \
# 0      -0.670354        0.394301    0.867200       -1.601539  ...
# 1      -0.670354        0.394301    0.867200        1.533927  ...
# 2       1.256703        0.394301   -1.153136       -0.974446  ...
# 3      -0.670354        0.394301    0.867200       -0.033806  ...
# 4      -0.670354       -2.536132    0.867200       -0.347352  ...
#
#    mod_work_activity  vig_work_activity  walk_bicycle  vig_rec_activity  \
# ...

# %%
import seaborn as sns

# %%
# https://www.geeksforgeeks.org/how-to-create-a-seaborn-correlation-heatmap-in-python/
# https://stackoverflow.com/questions/63964006/round-decimal-places-seaborn-heatmap-labels

plt.figure(figsize=(20,18))
p = sns.heatmap(merged_diabetes_df.corr(), cmap ='RdYlGn', annot=True, fmt='.2f')
